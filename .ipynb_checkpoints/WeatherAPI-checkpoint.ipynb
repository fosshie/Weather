# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %%
# OpenWeatherMap API Key
api_key = "7b2b78698384fb8c0b15f3f66c18696a"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=pevek
# Processing Record 2 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=cape%20town
# Processing Record 3 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=barrow
# Processing Record 4 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hilo
# Processing Record 5 of Set 1 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=samarai
# Processing Record 6 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=klaksvik
# Processing Record 7 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mataura
# Processing Record 8 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=provideniya
# Processing Record 9 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=albany
# Processing Record 10 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=port%20alfred
# Processing Record 11 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=vaini
# Processing Record 12 of Set 1 | vizinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=vizinga
# Processing Record 13 of Set 1 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tevaitoa
# Processing Record 14 of Set 1 | san jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=san%20jose
# Processing Record 15 of Set 1 | kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kaka
# Processing Record 16 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hithadhoo
# Processing Record 17 of Set 1 | vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=vysokogornyy
# Processing Record 18 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=castro
# Processing Record 19 of Set 1 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=muros
# Processing Record 20 of Set 1 | jember
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=jember
# Processing Record 21 of Set 1 | druzhba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=druzhba
# Processing Record 22 of Set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ilulissat
# Processing Record 23 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=lebu
# Processing Record 24 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bluff
# Processing Record 25 of Set 1 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=okha
# Processing Record 26 of Set 1 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ponta%20delgada
# Processing Record 28 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ushuaia
# Processing Record 29 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nikolskoye
# Processing Record 30 of Set 1 | svolvaer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=svolvaer
# Processing Record 31 of Set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=leningradskiy
# Processing Record 32 of Set 1 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=umm%20lajj
# Processing Record 33 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=rikitea
# Processing Record 34 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tiksi
# Processing Record 35 of Set 1 | masterton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=masterton
# Processing Record 36 of Set 1 | dianopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=dianopolis
# City not found. Skipping...
# Processing Record 37 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=cherskiy
# Processing Record 38 of Set 1 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tura
# Processing Record 39 of Set 1 | bafoulabe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bafoulabe
# Processing Record 40 of Set 1 | dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=dukat
# Processing Record 41 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hermanus
# Processing Record 42 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bredasdorp
# Processing Record 43 of Set 1 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=akyab
# City not found. Skipping...
# Processing Record 44 of Set 1 | samagaltay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=samagaltay
# Processing Record 45 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=chokurdakh
# Processing Record 46 of Set 1 | talbahat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=talbahat
# Processing Record 47 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=esperance
# Processing Record 48 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=dikson
# Processing Record 49 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=butaritari
# Processing Record 50 of Set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=belushya%20guba
# City not found. Skipping...
# Processing Record 0 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=atuona
# Processing Record 1 of Set 2 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=marcona
# City not found. Skipping...
# Processing Record 2 of Set 2 | hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hokitika
# Processing Record 3 of Set 2 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hervey%20bay
# Processing Record 4 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=severo-kurilsk
# Processing Record 5 of Set 2 | bonnyville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bonnyville
# Processing Record 6 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tasiilaq
# Processing Record 7 of Set 2 | doka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=doka
# Processing Record 8 of Set 2 | halkirk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=halkirk
# Processing Record 9 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=georgetown
# Processing Record 10 of Set 2 | veliki preslav
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=veliki%20preslav
# Processing Record 11 of Set 2 | panjab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=panjab
# Processing Record 12 of Set 2 | kawai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kawai
# Processing Record 13 of Set 2 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=abu%20samrah
# Processing Record 14 of Set 2 | cookshire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=cookshire
# City not found. Skipping...
# Processing Record 15 of Set 2 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bowen
# Processing Record 16 of Set 2 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sao%20joao%20da%20barra
# Processing Record 17 of Set 2 | odessa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=odessa
# Processing Record 18 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=punta%20arenas
# Processing Record 19 of Set 2 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=itoman
# Processing Record 20 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=jamestown
# Processing Record 21 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hobart
# Processing Record 22 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=saint%20george
# Processing Record 23 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=saint-philippe
# Processing Record 24 of Set 2 | ouesso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ouesso
# Processing Record 25 of Set 2 | hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hit
# Processing Record 26 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kodiak
# Processing Record 27 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=yellowknife
# Processing Record 28 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=avarua
# Processing Record 29 of Set 2 | snezhnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=snezhnogorsk
# Processing Record 30 of Set 2 | miyako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=miyako
# Processing Record 31 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=port%20elizabeth
# Processing Record 32 of Set 2 | calamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=calamar
# Processing Record 33 of Set 2 | ileza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ileza
# Processing Record 34 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mahebourg
# Processing Record 35 of Set 2 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=cabo%20san%20lucas
# Processing Record 36 of Set 2 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=rawson
# Processing Record 37 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bethel
# Processing Record 38 of Set 2 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kamenka
# Processing Record 39 of Set 2 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=palana
# Processing Record 40 of Set 2 | ankazoabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ankazoabo
# Processing Record 41 of Set 2 | furstenwalde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=furstenwalde
# Processing Record 42 of Set 2 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=katsuura
# Processing Record 43 of Set 2 | nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nadym
# Processing Record 44 of Set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=chuy
# Processing Record 45 of Set 2 | mosetse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mosetse
# Processing Record 46 of Set 2 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=severo-yeniseyskiy
# Processing Record 47 of Set 2 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ostrovnoy
# Processing Record 48 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=souillac
# Processing Record 0 of Set 3 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=yumen
# Processing Record 1 of Set 3 | aksay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=aksay
# Processing Record 2 of Set 3 | aracoiaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=aracoiaba
# Processing Record 3 of Set 3 | malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=malanje
# Processing Record 4 of Set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mys%20shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=pangai
# Processing Record 6 of Set 3 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=awjilah
# Processing Record 7 of Set 3 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mount%20isa
# Processing Record 9 of Set 3 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tautira
# Processing Record 10 of Set 3 | baza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=baza
# Processing Record 11 of Set 3 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=brae
# Processing Record 12 of Set 3 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=fairbanks
# Processing Record 13 of Set 3 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=half%20moon%20bay
# Processing Record 14 of Set 3 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=lagoa
# Processing Record 15 of Set 3 | gashua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=gashua
# Processing Record 16 of Set 3 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 3 | camargo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=camargo
# Processing Record 18 of Set 3 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kutum
# Processing Record 19 of Set 3 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=northam
# Processing Record 20 of Set 3 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kapaa
# Processing Record 21 of Set 3 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 22 of Set 3 | progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=progreso
# Processing Record 23 of Set 3 | kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kropotkin
# Processing Record 24 of Set 3 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=san%20quintin
# Processing Record 25 of Set 3 | sharya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sharya
# Processing Record 26 of Set 3 | novonukutskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=novonukutskiy
# Processing Record 27 of Set 3 | pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=pathein
# Processing Record 28 of Set 3 | yucaipa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=yucaipa
# Processing Record 29 of Set 3 | pombas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=pombas
# Processing Record 30 of Set 3 | macau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=macau
# Processing Record 31 of Set 3 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=narsaq
# Processing Record 32 of Set 3 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bengkulu
# City not found. Skipping...
# Processing Record 33 of Set 3 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=keti%20bandar
# Processing Record 35 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=saldanha
# Processing Record 36 of Set 3 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=busselton
# Processing Record 37 of Set 3 | auch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=auch
# Processing Record 38 of Set 3 | digby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=digby
# Processing Record 39 of Set 3 | zerind
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=zerind
# Processing Record 40 of Set 3 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=deputatskiy
# Processing Record 41 of Set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 3 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=praia%20da%20vitoria
# Processing Record 43 of Set 3 | encantado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=encantado
# Processing Record 44 of Set 3 | tatvan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tatvan
# Processing Record 45 of Set 3 | kazanskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kazanskaya
# Processing Record 46 of Set 3 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 3 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=saskylakh
# Processing Record 48 of Set 3 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=petropavlovsk-kamchatskiy
# Processing Record 49 of Set 3 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=derzhavinsk
# Processing Record 0 of Set 4 | papetoai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=papetoai
# Processing Record 1 of Set 4 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=namibe
# Processing Record 2 of Set 4 | phan rang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=phan%20rang
# City not found. Skipping...
# Processing Record 3 of Set 4 | quixada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=quixada
# City not found. Skipping...
# Processing Record 4 of Set 4 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kavieng
# Processing Record 5 of Set 4 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=charters%20towers
# Processing Record 6 of Set 4 | judenburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=judenburg
# Processing Record 7 of Set 4 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=port%20hardy
# Processing Record 8 of Set 4 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=upernavik
# Processing Record 9 of Set 4 | maputo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=maputo
# Processing Record 10 of Set 4 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=east%20london
# Processing Record 11 of Set 4 | asfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=asfi
# City not found. Skipping...
# Processing Record 12 of Set 4 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=burnie
# Processing Record 13 of Set 4 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=san%20juan
# Processing Record 14 of Set 4 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sabang
# Processing Record 15 of Set 4 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=iqaluit
# Processing Record 16 of Set 4 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=beloha
# Processing Record 17 of Set 4 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=arraial%20do%20cabo
# Processing Record 18 of Set 4 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=khatanga
# Processing Record 19 of Set 4 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=vardo
# Processing Record 20 of Set 4 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ribeira%20grande
# Processing Record 21 of Set 4 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=new%20norfolk
# Processing Record 22 of Set 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=qaanaaq
# Processing Record 23 of Set 4 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tuktoyaktuk
# Processing Record 24 of Set 4 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=padang
# Processing Record 25 of Set 4 | chiapilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=chiapilla
# Processing Record 26 of Set 4 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=lata
# Processing Record 27 of Set 4 | soe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=soe
# Processing Record 28 of Set 4 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 4 | mandera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mandera
# Processing Record 30 of Set 4 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=necochea
# Processing Record 31 of Set 4 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ahipara
# Processing Record 32 of Set 4 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=asau
# City not found. Skipping...
# Processing Record 33 of Set 4 | tifton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tifton
# Processing Record 34 of Set 4 | staraya toropa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=staraya%20toropa
# Processing Record 35 of Set 4 | kota belud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kota%20belud
# Processing Record 36 of Set 4 | zakamensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=zakamensk
# Processing Record 37 of Set 4 | beipiao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=beipiao
# Processing Record 38 of Set 4 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mar%20del%20plata
# Processing Record 39 of Set 4 | aljezur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=aljezur
# Processing Record 40 of Set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=victoria
# Processing Record 41 of Set 4 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sorong
# Processing Record 42 of Set 4 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nanortalik
# Processing Record 43 of Set 4 | sao joao evangelista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sao%20joao%20evangelista
# Processing Record 44 of Set 4 | mahalapye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mahalapye
# Processing Record 45 of Set 4 | kasama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kasama
# Processing Record 46 of Set 4 | ust-bolsheretsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ust-bolsheretsk
# City not found. Skipping...
# Processing Record 47 of Set 4 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=pangnirtung
# Processing Record 48 of Set 4 | kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kisangani
# Processing Record 49 of Set 4 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=flinders
# Processing Record 0 of Set 5 | bulgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bulgan
# Processing Record 1 of Set 5 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sao%20filipe
# Processing Record 2 of Set 5 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ulaangom
# Processing Record 3 of Set 5 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=strezhevoy
# Processing Record 4 of Set 5 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=talnakh
# Processing Record 5 of Set 5 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=salinopolis
# Processing Record 6 of Set 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=san%20cristobal
# Processing Record 7 of Set 5 | masuguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=masuguru
# Processing Record 8 of Set 5 | sobradinho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sobradinho
# Processing Record 9 of Set 5 | sirohi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sirohi
# Processing Record 10 of Set 5 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=comodoro%20rivadavia
# Processing Record 11 of Set 5 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=leshukonskoye
# Processing Record 12 of Set 5 | saint-paul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=saint-paul
# Processing Record 13 of Set 5 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 5 | changde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=changde
# Processing Record 15 of Set 5 | maksatikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=maksatikha
# Processing Record 16 of Set 5 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=airai
# Processing Record 17 of Set 5 | bandrele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bandrele
# Processing Record 18 of Set 5 | astoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=astoria
# Processing Record 19 of Set 5 | ostroda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ostroda
# Processing Record 20 of Set 5 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=roma
# Processing Record 21 of Set 5 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=palmer
# Processing Record 22 of Set 5 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kahului
# Processing Record 23 of Set 5 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 5 | dieppe bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=dieppe%20bay
# City not found. Skipping...
# Processing Record 25 of Set 5 | dumas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=dumas
# Processing Record 26 of Set 5 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sorland
# Processing Record 27 of Set 5 | casa nova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=casa%20nova
# Processing Record 28 of Set 5 | bengkalis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bengkalis
# City not found. Skipping...
# Processing Record 29 of Set 5 | den helder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=den%20helder
# Processing Record 30 of Set 5 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=srednekolymsk
# Processing Record 31 of Set 5 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 5 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=chapais
# Processing Record 33 of Set 5 | abashiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=abashiri
# Processing Record 34 of Set 5 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kavaratti
# Processing Record 35 of Set 5 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=aklavik
# Processing Record 36 of Set 5 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mount%20gambier
# Processing Record 37 of Set 5 | cincinnati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=cincinnati
# Processing Record 38 of Set 5 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=saint-augustin
# Processing Record 39 of Set 5 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=port%20lincoln
# Processing Record 40 of Set 5 | west bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=west%20bay
# Processing Record 41 of Set 5 | missoula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=missoula
# Processing Record 42 of Set 5 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tommot
# Processing Record 43 of Set 5 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hofn
# Processing Record 44 of Set 5 | fagersta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=fagersta
# Processing Record 45 of Set 5 | joao pinheiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=joao%20pinheiro
# Processing Record 46 of Set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=faanui
# Processing Record 47 of Set 5 | moindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=moindou
# Processing Record 48 of Set 5 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=chara
# Processing Record 49 of Set 5 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bubaque
# Processing Record 0 of Set 6 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=henties%20bay
# Processing Record 2 of Set 6 | severomuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=severomuysk
# Processing Record 3 of Set 6 | morehead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=morehead
# Processing Record 4 of Set 6 | eyrarbakki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=eyrarbakki
# Processing Record 5 of Set 6 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mandalgovi
# Processing Record 6 of Set 6 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=cabedelo
# Processing Record 7 of Set 6 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=puerto%20ayora
# Processing Record 8 of Set 6 | toucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=toucheng
# Processing Record 9 of Set 6 | hulan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hulan
# Processing Record 10 of Set 6 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=puerto%20escondido
# Processing Record 11 of Set 6 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=champerico
# Processing Record 12 of Set 6 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hasaki
# Processing Record 13 of Set 6 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=pisco
# Processing Record 14 of Set 6 | madison heights
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=madison%20heights
# Processing Record 15 of Set 6 | powell river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=powell%20river
# Processing Record 16 of Set 6 | ledyard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ledyard
# Processing Record 17 of Set 6 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=iquique
# Processing Record 18 of Set 6 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=carnarvon
# Processing Record 19 of Set 6 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ponta%20do%20sol
# Processing Record 20 of Set 6 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=la%20ronge
# Processing Record 21 of Set 6 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=norman%20wells
# Processing Record 22 of Set 6 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=manokwari
# Processing Record 23 of Set 6 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=taoudenni
# Processing Record 24 of Set 6 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ahuimanu
# Processing Record 25 of Set 6 | dvinskoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=dvinskoy
# Processing Record 26 of Set 6 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=meulaboh
# Processing Record 27 of Set 6 | kryve ozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kryve%20ozero
# Processing Record 28 of Set 6 | hukuntsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hukuntsi
# Processing Record 29 of Set 6 | yamada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=yamada
# Processing Record 30 of Set 6 | bonao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bonao
# Processing Record 31 of Set 6 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=russell
# Processing Record 32 of Set 6 | orbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=orbe
# Processing Record 33 of Set 6 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=longyearbyen
# Processing Record 34 of Set 6 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=taltal
# Processing Record 35 of Set 6 | sayat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sayat
# Processing Record 36 of Set 6 | tanabe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tanabe
# Processing Record 37 of Set 6 | chimore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=chimore
# Processing Record 38 of Set 6 | snizhne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=snizhne
# Processing Record 39 of Set 6 | rudnichnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=rudnichnyy
# Processing Record 40 of Set 6 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=labuhan
# Processing Record 41 of Set 6 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=thompson
# Processing Record 42 of Set 6 | sinkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sinkat
# City not found. Skipping...
# Processing Record 43 of Set 6 | zhengjiatun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=zhengjiatun
# Processing Record 44 of Set 6 | artyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=artyk
# City not found. Skipping...
# Processing Record 45 of Set 6 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=raudeberg
# Processing Record 46 of Set 6 | nha trang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nha%20trang
# Processing Record 47 of Set 6 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=grand%20gaube
# Processing Record 48 of Set 6 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=dauphin
# Processing Record 49 of Set 6 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=zyryanka
# Processing Record 0 of Set 7 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nuuk
# Processing Record 1 of Set 7 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=codrington
# Processing Record 2 of Set 7 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=merauke
# Processing Record 3 of Set 7 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=clyde%20river
# Processing Record 4 of Set 7 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hovd
# Processing Record 5 of Set 7 | umzimvubu
# ...
# Processing Record 21 of Set 11 | skalistyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 11 | kittery
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kittery
# Processing Record 23 of Set 11 | obidos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=obidos
# Processing Record 24 of Set 11 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=anadyr
# Processing Record 25 of Set 11 | san felipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=san%20felipe
# Processing Record 26 of Set 11 | mananjary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mananjary
# Processing Record 27 of Set 11 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=evensk
# Processing Record 28 of Set 11 | mangaluru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mangaluru
# Processing Record 29 of Set 11 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=saint%20anthony
# Processing Record 30 of Set 11 | concarneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=concarneau
# Processing Record 31 of Set 11 | ankang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ankang
# Processing Record 32 of Set 11 | staunton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=staunton
# Processing Record 33 of Set 11 | tara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tara
# Processing Record 34 of Set 11 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=inirida
# Processing Record 35 of Set 11 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mayo
# Processing Record 36 of Set 11 | panzhihua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=panzhihua
# Processing Record 37 of Set 11 | kazanskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kazanskoye
# City not found. Skipping...
# Processing Record 38 of Set 11 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=alta%20floresta
# Processing Record 39 of Set 11 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=yar-sale
# Processing Record 40 of Set 11 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=okhotsk
# Processing Record 41 of Set 11 | capao bonito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=capao%20bonito
# Processing Record 42 of Set 11 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=takoradi
# Processing Record 43 of Set 11 | vung tau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=vung%20tau
# Processing Record 44 of Set 11 | luwingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=luwingu
# Processing Record 45 of Set 11 | balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=balkanabat
# Processing Record 46 of Set 11 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=fort%20nelson
# Processing Record 47 of Set 11 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=belyy%20yar
# Processing Record 48 of Set 11 | yefira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=yefira
# City not found. Skipping...
# Processing Record 49 of Set 11 | srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=srandakan
# Processing Record 0 of Set 12 | paramirim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=paramirim
# Processing Record 1 of Set 12 | nizhniy odes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nizhniy%20odes
# Processing Record 2 of Set 12 | rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=rundu
# Processing Record 3 of Set 12 | puerto madryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=puerto%20madryn
# Processing Record 4 of Set 12 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hambantota
# Processing Record 5 of Set 12 | tarboro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tarboro
# Processing Record 6 of Set 12 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hay%20river
# Processing Record 7 of Set 12 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=launceston
# Processing Record 8 of Set 12 | tarauaca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tarauaca
# Processing Record 9 of Set 12 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=richards%20bay
# Processing Record 10 of Set 12 | sahrak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sahrak
# City not found. Skipping...
# Processing Record 11 of Set 12 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hobyo
# Processing Record 12 of Set 12 | lodwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=lodwar
# Processing Record 13 of Set 12 | nosivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nosivka
# Processing Record 14 of Set 12 | voh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=voh
# Processing Record 15 of Set 12 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=saint-pierre
# Processing Record 16 of Set 12 | kucove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kucove
# Processing Record 17 of Set 12 | kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kokopo
# Processing Record 18 of Set 12 | aginskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=aginskoye
# Processing Record 19 of Set 12 | galiwinku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 12 | bousso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bousso
# City not found. Skipping...
# Processing Record 21 of Set 12 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=goderich
# Processing Record 22 of Set 12 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=haines%20junction
# Processing Record 23 of Set 12 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=mitsamiouli
# Processing Record 24 of Set 12 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=quatre%20cocos
# Processing Record 25 of Set 12 | puerto triunfo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=puerto%20triunfo
# Processing Record 26 of Set 12 | maryville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=maryville
# Processing Record 27 of Set 12 | aberdeen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=aberdeen
# Processing Record 28 of Set 12 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=port%20macquarie
# Processing Record 29 of Set 12 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=port-cartier
# Processing Record 30 of Set 12 | falealupo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=falealupo
# City not found. Skipping...
# Processing Record 31 of Set 12 | limbang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=limbang
# Processing Record 32 of Set 12 | kapit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kapit
# Processing Record 33 of Set 12 | allapalli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=allapalli
# Processing Record 34 of Set 12 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=acarau
# City not found. Skipping...
# Processing Record 35 of Set 12 | high level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=high%20level
# Processing Record 36 of Set 12 | muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=muli
# Processing Record 37 of Set 12 | butterworth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=butterworth
# Processing Record 38 of Set 12 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=pacifica
# Processing Record 39 of Set 12 | santiago de cao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=santiago%20de%20cao
# Processing Record 40 of Set 12 | panguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=panguna
# Processing Record 41 of Set 12 | tiradentes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tiradentes
# Processing Record 42 of Set 12 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=vangaindrano
# Processing Record 43 of Set 12 | barbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=barbar
# City not found. Skipping...
# Processing Record 44 of Set 12 | atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=atambua
# Processing Record 45 of Set 12 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=aflu
# City not found. Skipping...
# Processing Record 46 of Set 12 | katano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=katano
# Processing Record 47 of Set 12 | lichuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=lichuan
# Processing Record 48 of Set 12 | kayerkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=kayerkan
# Processing Record 49 of Set 12 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=santa%20rosa
# Processing Record 0 of Set 13 | agaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=agaro
# Processing Record 1 of Set 13 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=lorengau
# Processing Record 2 of Set 13 | arona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=arona
# Processing Record 3 of Set 13 | ust-ordynskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=ust-ordynskiy
# Processing Record 4 of Set 13 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=caravelas
# Processing Record 5 of Set 13 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=honningsvag
# Processing Record 6 of Set 13 | nagato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nagato
# Processing Record 7 of Set 13 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=bonthe
# Processing Record 8 of Set 13 | sao lourenco da mata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=sao%20lourenco%20da%20mata
# Processing Record 9 of Set 13 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=geraldton
# Processing Record 10 of Set 13 | hurghada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=hurghada
# City not found. Skipping...
# Processing Record 11 of Set 13 | rock springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=rock%20springs
# Processing Record 12 of Set 13 | shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=shakawe
# Processing Record 13 of Set 13 | gilroy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=gilroy
# Processing Record 14 of Set 13 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=eureka
# Processing Record 15 of Set 13 | nam tha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=nam%20tha
# City not found. Skipping...
# Processing Record 16 of Set 13 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=vao
# Processing Record 17 of Set 13 | avanigadda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=avanigadda
# Processing Record 18 of Set 13 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=te%20anau
# Processing Record 19 of Set 13 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=tabou
# Processing Record 20 of Set 13 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b2b78698384fb8c0b15f3f66c18696a&q=cap%20malheureux
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()

# Display the City Data Frame
city_data_pd.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7c2b6789409f> in <module>()
#      10
#      11 # Export the City_Data into a csv
# ---> 12 city_data_pd.to_csv(output_data_file, index_label="City_ID")
#      13
#      14 # Show Record Count
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# --> 156                                      compression=self.compression)
#     157             close = True
#     158
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/cities.csv'

# %%
# Build scatter plot for latitude vs temperature
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for each city types
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for each city types
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for each city types
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
